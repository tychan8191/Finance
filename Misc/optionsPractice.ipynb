# %%
import yfinance as yf

# %%
tsla = yf.Ticker("TSLA")
allExpiries = tsla.options

# %%
expiry = allExpiries[0]
opt_chain = tsla.option_chain(expiry)

calls = opt_chain.calls
puts = opt_chain.puts

print("\nCalls:\n", calls.head())
print("\nPuts:\n",  puts.head())
# Out:
# Calls:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0  TSLA260102C00080000 2025-12-29 15:13:22+00:00    80.0     382.29  380.25
# 1  TSLA260102C00100000 2025-12-29 15:40:38+00:00   100.0     367.73  361.45
# 2  TSLA260102C00120000 2025-12-29 14:30:24+00:00   120.0     345.95  341.40
# 3  TSLA260102C00140000 2025-12-15 14:35:40+00:00   140.0     327.76  321.40
# 4  TSLA260102C00150000 2025-12-29 14:39:08+00:00   150.0     315.88  311.50
#
#       ask     change  percentChange  volume  openInterest  impliedVolatility  \
# 0  386.20 -32.209990      -7.770806    10.0             6           6.802736
# 1  365.95 -10.419983      -2.755516    40.0             4           6.419924
# 2  346.80  11.279999       3.370484     2.0             2           5.951174
# 3  326.20 -10.089996      -2.986531     2.0             6           5.120121
# 4  316.85 -19.619995      -5.847987     4.0            10           5.051761
#
#    inTheMoney contractSize currency
# ...
